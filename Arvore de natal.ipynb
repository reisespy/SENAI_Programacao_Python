# %%
# -*- coding: UTF-8 -*-
"""
Código desenvolvido por Ariel Reises
No curso de Programação Python do Senai Alfried Krupp - Campo Limpo Paulista
28 de julho de 2023
"""

#Desenhando a árvore
def desenhar_arvore_altura(altura):
    for i in range(1, altura + 1):
        espacos = altura - i
        asteriscos = 2 * i - 1
        print(" " * espacos + "*" * asteriscos)

#Desenhando o tronco da árvore
    tronco_altura = altura // 3
    tronco_largura = altura // 3
    tronco_posicao = altura - tronco_altura
    for _ in range(tronco_altura):
        espacos_tronco = altura - tronco_largura // 2
        print(" " * espacos_tronco + "*" * tronco_largura)

#Solicitando a altura da árvore (sem tronco)
def main():
    altura_arvore = int(input("Digite a altura da árvore de Natal: "))
    desenhar_arvore_altura(altura_arvore)


if __name__ == "__main__":
    main()

#Assinatura - Ariel Reises
print("")
print("Obrigado por utilizar o sistema")
print("Copyright © 2023 - reises.py")
# Out:
# Digite a altura da árvore de Natal: 10
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************
#          ***
#          ***
#          ***
