# %%
# -*- coding: UTF-8 -*-
"""
Código desenvolvido por Ariel Reises
No curso de Programação Python do Senai Alfried Krupp - Campo Limpo Paulista
01 de agosto de 2023
"""

#Apresentação inicial
print("Olá, este programa inverterá os valores das variáveia A e B inseridas.")
print("")
print("Insira abaixo as variáveis desejadas")

#Criação das variáveis
variavel_a = int(input("Insira a variável A: "))
variavel_b = int(input("Insira a variável B: "))
variavel_a2 = variavel_b
variavel_b2 = variavel_a
inversao = (variavel_a2, variavel_b2)

#Apresentação do resultado
print("")
print(f"O resultado da inversão das variáveis é: {inversao}")

#Assinatura - Ariel Reises
print("")
print("Obrigado por utilizar o sistema")
print("Copyright © 2023 - reises.py")
# Out:
# Olá, este programa inverterá os valores das variáveia A e B inseridas.
#
# Insira abaixo as variáveis desejadas
# Insira a variável A: 6
# Insira a variável B: 7
#
# O resultado da inversão das variáveis é: (7, 6)
#
# Obrigado por utilizar o sistema
# Copyright © 2023 - reises.py
